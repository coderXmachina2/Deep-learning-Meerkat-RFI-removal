# %%
#A script that takes in a text file

n_epoch = 7 #we trained for 7 epochs

with open("epochalTrainingEvolution.txt", "a") as p:
    with open("stackTrace-2019-12-09-03.txt", "r") as f:
        lines = f.readlines()
        for t in range(0, len(lines)):
            if ("acc" in lines[t] or lines[t].startswith("Epoch")):
                
                print(lines[t])
                p.write(lines[t])
                #writes line to text file
# Out:
# Epoch 1/7
#
#   1/150 [..............................] - ETA: 2:18:00 - loss: 0.8102 - acc: 0.5008
#
#   2/150 [..............................] - ETA: 2:04:56 - loss: 0.7038 - acc: 0.5928
#
#   3/150 [..............................] - ETA: 2:00:45 - loss: 0.6393 - acc: 0.6478
#
#   4/150 [..............................] - ETA: 1:58:28 - loss: 0.5729 - acc: 0.6986
#
#   5/150 [>.............................] - ETA: 1:56:40 - loss: 0.5233 - acc: 0.7360
#
#   6/150 [>.............................] - ETA: 1:54:42 - loss: 0.4887 - acc: 0.7613
#
#   7/150 [>.............................] - ETA: 1:53:35 - loss: 0.4468 - acc: 0.7866
#
#   8/150 [>.............................] - ETA: 1:52:41 - loss: 0.4214 - acc: 0.8034
#
#   9/150 [>.............................] - ETA: 1:51:23 - loss: 0.4080 - acc: 0.8124
#
#  10/150 [=>............................] - ETA: 1:50:44 - loss: 0.3955 - acc: 0.8217
#
#  11/150 [=>............................] - ETA: 1:49:48 - loss: 0.3848 - acc: 0.8285
#
# ...

# %%
#what can we plot? Across Epochs?
#take out 
import re

with open("time-loss.txt", "a") as p:
    with open("epochalEvolution.txt", "r") as f:
        lines = f.readlines()
        #print(lines)
        for t in range(0, len(lines)):
            #re.search('asdf=5;(.*)123jasd', s)
            ETA = re.findall('ETA: (.*) - loss:', lines[t])
            print(str(ETA).strip('[]'))
            p.write(str(ETA).strip('[]'))
                
#time on x axis,

#loss on the y axis
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-70e9dc905422> in <module>
#       4
#       5 with open("time-loss.txt", "a") as p:
# ----> 6     with open("epochalEvolution.txt", "r") as f:
#       7         lines = f.readlines()
#       8         #print(lines)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'epochalEvolution.txt'

# %%
with open("time-loss.txt", "a") as p:
    with open("epochalEvolution.txt", "r") as f:
        lines = f.readlines()
        #print(lines)
        for t in range(0, len(lines)):
            loss = re.findall('loss: (.*) - acc:', lines[t])
            print(loss)
            #acc = re.findall('acc: (.*)\n', lines[t])
            #print(acc)
            #print(match[0])
            #print(lines[t])
            #if ("acc" in lines[t] or lines[t].startswith("Epoch")):
                
#time on x axis,

#loss on the y axis
# Out:
# []
# ['0.8102']
# ['0.7038']
# ['0.6393']
# ['0.5729']
# ['0.5233']
# ['0.4887']
# ['0.4468']
# ['0.4214']
# ['0.4080']
# ['0.3955']
# ['0.3848']
# ['0.3671']
# ['0.3561']
# ['0.3447']
# ['0.3361']
# ['0.3309']
# ['0.3237']
# ['0.3170']
# ['0.3101']
# ['0.3077']
# ['0.3014']
# ['0.2975']
# ['0.2935']
# ['0.2885']
# ['0.2835']
# ['0.2818']
# ['0.2794']
# ['0.2761']
# ['0.2718']
# ['0.2674']
# ['0.2654']
# ['0.2622']
# ['0.2601']
# ['0.2568']
# ['0.2536']
# ['0.2509']
# ['0.2485']
# ['0.2465']
# ['0.2453']
# ['0.2423']
# ['0.2397']
# ['0.2378']
# ['0.2364']
# ['0.2355']
# ['0.2332']
# ['0.2319']
# ['0.2304']
# ['0.2293']
# ['0.2281']
# ['0.2260']
# ['0.2244']
# ['0.2237']
# ['0.2222']
# ['0.2210']
# ['0.2203']
# ['0.2192']
# ['0.2178']
# ['0.2167']
# ['0.2158']
# ['0.2145']
# ['0.2139']
# ['0.2126']
# ['0.2115']
# ['0.2105']
# ['0.2093']
# ['0.2081']
# ['0.2068']
# ['0.2059']
# ['0.2046']
# ['0.2034']
# ['0.2024']
# ['0.2014']
# ['0.2005']
# ['0.2002']
# ['0.1992']
# ['0.1987']
# ...
