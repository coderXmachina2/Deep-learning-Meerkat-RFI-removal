# %%
#Track the Generator by Epoch
import re
#take the script where you processed the text

n_epoch = 7 #we trained for 7 epochs

with open('GANAccuracies02.txt', "w") as w:
    with open("10keps02.txt", "r") as t:
        lines = t.readlines()
        for n in range(0, len(lines)):
            if ("acc" in lines[n] or lines[n].startswith("Epoch")):
                print(lines[n])
                result = re.search('acc.: (.*)%', lines[n])
                print(result.group(1))
                w.write(result.group(1) + "\n")
                #p.write(str(ETA).strip('[]'))
# Out:
# 1 [D loss: 0.433315, acc.: 87.50%] [G loss: 0.860877]
#
# 87.50
# 2 [D loss: 0.350263, acc.: 88.64%] [G loss: 0.855243]
#
# 88.64
# 3 [D loss: 0.331562, acc.: 86.36%] [G loss: 0.848430]
#
# 86.36
# 4 [D loss: 0.324577, acc.: 86.36%] [G loss: 0.923780]
#
# 86.36
# 5 [D loss: 0.306790, acc.: 91.29%] [G loss: 0.989573]
#
# 91.29
# 6 [D loss: 0.288258, acc.: 93.18%] [G loss: 1.090485]
#
# 93.18
# 7 [D loss: 0.255156, acc.: 96.21%] [G loss: 1.128042]
#
# 96.21
# 8 [D loss: 0.225985, acc.: 99.24%] [G loss: 1.303605]
#
# 99.24
# 9 [D loss: 0.200149, acc.: 98.86%] [G loss: 1.444092]
#
# 98.86
# 10 [D loss: 0.169969, acc.: 100.00%] [G loss: 1.520815]
#
# 100.00
# 11 [D loss: 0.147880, acc.: 100.00%] [G loss: 1.647840]
#
# 100.00
# 12 [D loss: 0.148281, acc.: 99.62%] [G loss: 1.781500]
#
# 99.62
# 13 [D loss: 0.123607, acc.: 100.00%] [G loss: 1.880689]
#
# 100.00
# 14 [D loss: 0.104458, acc.: 100.00%] [G loss: 1.963830]
#
# 100.00
# 15 [D loss: 0.103396, acc.: 100.00%] [G loss: 2.107900]
#
# ...
